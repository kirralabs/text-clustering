# %%
import kirra_libs as LIBS
import os, mpld3, nltk
import numpy as np
import pandas as pd
os.chdir(".")
SOURCE_DATA_FILE = "../../data"

# %%
# get all file ".txt" in folder data
df = pd.DataFrame(columns=['title', 'desc'])
listfile = LIBS.getAllFileinFolder(SOURCE_DATA_FILE)
listfile[:10] #print 10 filename
# Out:
# ['../../data/tempo/010210/010210-115.txt',
#  '../../data/tempo/010210/010210-1132.txt',
#  '../../data/tempo/010210/010210-1134.txt',
#  '../../data/tempo/010210/010210-1124.txt',
#  '../../data/tempo/010210/010210-1130.txt',
#  '../../data/tempo/010210/010210-1136.txt',
#  '../../data/tempo/010210/010210-1116.txt',
#  '../../data/tempo/010210/010210-1133.txt',
#  '../../data/tempo/010210/010210-1110.txt',
#  '../../data/tempo/010210/010210-111.txt']

# %%
inc = 0
for filename in listfile[:200]:
    data = open("{}".format(filename), "r").readlines()
    try:  
        title = data[0].strip()
        desc = " ".join(data[1:]).strip().replace("\n","")
        #replace multiple space
        desc = ' '.join(desc.split())
        df.loc[inc] = [title, desc]
        inc += 1
    except:
        pass
df
# Out:
#                                                  title  \
# 0         Akri Patrio Masuk Ruang Isolasi RS Pertamina
# 1                 Bambang Kesowo Bantah Telepon Taufik
# 2                         Yusril Datang ke LP Cipinang
# 3    Penyelidikan Pelanggaran HAM Tidak Terkait den...
# 4                      200 Ribu Gula Impor Salahi Izin
# 5                  Korban Tewas di Cipinang Satu Orang
# 6             Warga PDI-P agar Bersikap Anti Kekerasan
# 7             Puluhan Senjata Tajam Disita di Cipinang
# 8                             Indeks Melemah di Sesi I
# 9      Eko dan Akri Patrio Terbakar, Masuk Rumah Sakit
# 10                       LP Cipinang Rusuh, Satu Tewas
# 11                  MA Bertindak Heroik dalam PK Tommy
# 12      Lalu Lintas di Depan Pasar Cipulir Masih Macet
# 13       Pengacara Tommy Minta Salinan Keputusan ke MA
# 14                      Polisi  Sweeping   LP Cipinang
# 15       Wapres Berharap Masyarakat Hormati Putusan MA
# 16        Putusan PK Tommy Atas Sepengetahuan Rapim MA
# 17          M. Taufik Sadar Keputusannya Kontroversial
# 18                     Tommy Serahkan Diri Oktober Ini
# 19       Majelis Hakim Memutus Dengan Sangat Hati-hati
# 20   Kejagung Bisa Lakukan PK Terhadap Keputusan PK MA
# 21     MA Memberi Contoh Buruk dalam Pelaksanaan Hukum
# 22                  Rusdiharjo Calon Kuat Hakim Ad Hoc
# 23          KSAD Membenarkan Ada Mutasi Perwira Tinggi
# 24                                  IHSG Terus Melemah
# 25       Keputusan MA Bukan Karena Tewasnya Syafiuddin
# 26              105 Napi Cipinang Dievakuasi Malam Ini
# 27   Megawati Instruksikan Anggota PDI-P Isi Formul...
# 28               Tommy Tak Menampakkan Diri di Cendana
# 29     Dipahami Formalistik, Agama Jadi Sumber Konflik
# ..                                                 ...
# 170                   Pengacara Minta Elize Dibebaskan
# 171  HKTI Minta Pemerintah Lebih Perhatikan Nasib P...
# 21   Staf ahli Menteri Kehakiman dan Hak Azasi Manu...
# 22   Mantan Kapolri Jenderal Polisi Rusdihardjo dis...
# 23   Kepala Staf Angkatan Darat, Jendral TNI Endria...
# 24   Indeks harga saham (IHSG) pada sesi penutupan ...
# 25   Ketua MA Bagir Manan membantah keputusan penin...
# 26   Sebanyak 105 narapidana bermasalah di LP Cipin...
# 27   Ketua Umum DPP PDI-P Megawati Soekarnoputri te...
# 28   Hingga pukul 23.00 WIB, Senin (1/10) malam, ta...
# 29   Mantan Presiden KH Abdurrahman Wahid prihatin ...
# ..                                                 ...
# 170  Jika hasil pemeriksaan kesehatan Elize Maria T...
# 171  Himpunan Kerukunan Tani Indonesia (HKTI) memin...
# 172  Makar adalah setiap usaha untuk menggulingkan ...
# 173  Mantan Jaksa Agung Andi M Ghalib akan dipanggi...
# 174  Wakil Panglima GAM Wilayah Pasee, Sofyan Daud,...
# 175  Hutomo Mandala Putra alias Tommy Soeharto terc...
# 176  Gubernur Aceh, Ir H Abdullah Puteh MSi mengata...
# 177  Puluhan massa menyerbu serta merusak Hotel Oas...
# 178  Sebanyak 400 calon haji dari berbagai daerah t...
# 179  Pemerintah merencanakan menerapkan tiga harga ...
# 180  Hingga Rabu (24/1), Pansus Amandemen UU Bank I...
# 181  Sembilan unit kios di Desa Tanjong Minje Kecam...
# 182  Hari ini, Camat Tanah Abang mempertemukan dua ...
# 183  Pemeriksaan terhadap tersangka Syamsul Nursali...
# 184  Wakil Gubernur Sulawesi Utara Freddy H. Sualan...
# 185  Ribuan armada Angkutan Umum yang tergabung dal...
# 186  Tempat transaksi senjata api ilegal di wilayah...
# 187  Pemerintah akhirnya memutuskan menunda untuk m...
# 188  PT Dirgantara Indonesia, dulu bernama IPTN, Ka...
# 189  Sekitar 200 buruh PT Indometal Sejati Kedaung,...
# 190  Pemerintah akan segera melakukan restrukturisa...
# 191  Terdakwa Mohamad Hasan atau Bob Hassan membaca...
# 192  Dalam operasi mulai 15 hingga 20 Januari, apar...
# 193  Ekses dari penembakan yang dilakukan gerilyawa...
# 194  Gelombang pengunduran pengurus Partai Amanat N...
# 195  Surat izin penahanan terhadap mantan Menteri P...
# 196  Juru Bicara Kepresidenan Adhi M Massardi menga...
# 197  Menteri Luar Negeri Alwi Shihab membantah adan...
# 198  Ketua Yayasan Paramadina, Dr Komaruddin Hidaya...
# 199  Partai Golkar tidak mempermasalahkan permintaa...
#
# [200 rows x 2 columns]

# %%
df['title'].values
# df['desc'].values[:10]
# Out:
# array(['Akri Patrio Masuk Ruang Isolasi RS Pertamina',
#        'Bambang Kesowo Bantah Telepon Taufik',
#        'Yusril Datang ke LP Cipinang',
#        'Penyelidikan Pelanggaran HAM Tidak Terkait dengan Bantuan AS',
#        '200 Ribu Gula Impor Salahi Izin',
#        'Korban Tewas di Cipinang Satu Orang',
#        'Warga PDI-P agar Bersikap Anti Kekerasan',
#        'Puluhan Senjata Tajam Disita di Cipinang',
#        'Indeks Melemah di Sesi I',
#        'Eko dan Akri Patrio Terbakar, Masuk Rumah Sakit',
#        'LP Cipinang Rusuh, Satu Tewas',
#        'MA Bertindak Heroik dalam PK Tommy',
#        'Lalu Lintas di Depan Pasar Cipulir Masih Macet',
#        'Pengacara Tommy Minta Salinan Keputusan ke MA',
#        'Polisi  Sweeping   LP Cipinang',
#        'Wapres Berharap Masyarakat Hormati Putusan MA',
#        'Putusan PK Tommy Atas Sepengetahuan Rapim MA',
#        'M. Taufik Sadar Keputusannya Kontroversial',
#        'Tommy Serahkan Diri Oktober Ini',
#        'Majelis Hakim Memutus Dengan Sangat Hati-hati',
#        'Kejagung Bisa Lakukan PK Terhadap Keputusan PK MA',
#        'MA Memberi Contoh Buruk dalam Pelaksanaan Hukum',
#        'Rusdiharjo Calon Kuat Hakim Ad Hoc',
#        'KSAD Membenarkan Ada Mutasi Perwira Tinggi', 'IHSG Terus Melemah',
#        'Keputusan MA Bukan Karena Tewasnya Syafiuddin',
#        '105 Napi Cipinang Dievakuasi Malam Ini',
#        'Megawati Instruksikan Anggota PDI-P Isi Formulir KPKPN',
#        'Tommy Tak Menampakkan Diri di Cendana',
#        'Dipahami Formalistik, Agama Jadi Sumber Konflik',
#        'KPKPN Telah Terima Daftar Kekayaan 56 Hakim Agung',
#        '300 Polisi Amankan LP Cipinang',
#        'Kunjungan Wapres ke Daerah Termasuk Korupsi Jabatan',
#        'Ratusan Orang Demo Anti  Sweeping  di Denpasar',
#        'Wapres Kembali Tegaskan Pembangunan Ekonomi Sektor Riil',
#        'NU-Muhammadiyah Sulsel Rukun', 'Indorayon Segera Ganti Nama',
#        'Pemerintah Belum Tentu Lantik Gubernur Aceh Terpilih',
#        'Gubernur Jatim Minta Warga NU Cabut Pencekalan',
#        'Konflik Gelbard-Indonesia Hanya Permainan Politik',
#        'Digelar: Kongres Korban Kekerasan Aceh',
#        'Annan Minta Makarim Jadi Penasehat Informasi',
#        'Polisi Tambah Pasukan Pengamanan Bumi Dipasena',
#        'Abdullah Puteh Raih Suara Terbanyak',
#        'Polisi Duga Pengeboman Bermotif Ekonomi',
#        'Meski Sudah Aman, Aparat Masih Berjaga-jaga',
#        'Rupiah Paling Banyak Dispekulasikan di Singapura',
#        'Indonesia dan Untaet Diskusikan Pemulangan Pengungsi',
#        'Panitia Penyelidikan Perubahan UUD 1945 Hanya Memberi Masukan',
#        'Imigran Irak Gelar Unjuk Rasa di UNHCR',
#        'Grup Lippo Juga Sumbang US$ 2.000 ke Partai Republik',
#        'PPh Bunga Deposito Tidak Menimbulkan Capital Flight',
#        'Mahasiswa Bali Gelar demo Anti-Gus Dur',
#        'Sea Games Bukan Target PB PBSI',
#        'Birokrasi Pemerintahan di Aceh Akan Dinormalisasi',
#        'Tersangka Pembawa Bom Ditangkap',
#        'Sepak Takraw Indonesia Hanya Targetkan Perunggu',
#        'Kader PDIP Pimpin DPRD Sumatera Utara',
#        'Kejagung Sulit Menyusun Dakwaan Beddu',
#        'Amandemen UU BI  Masih Prematur',
#        'Lagi, Perampas Motor Dibakar Massa',
#        'Korban Banjir di Mataram Butuh Bantuan Rp 14 Miliar',
#        'Pansus Dianggap Telah Memaksakan Rumusan Akhir',
#        'FKM Ancam Gugat Pemerintah Indonesia',
#        'Kejari Jaksel Gagal Memeriksa Bob Hasan',
#        'Seribu Massa Gelar AKsi Solidaritas ke Mapolda',
#        'Pemerintah akan Bentuk Panitia Penyelidik Konstitusi',
#        'Memicu Indeks Saham BEJ Turun 4,787 Poin',
#        'Suwondo Penuhi Panggilan Panitia Khusus',
#        'Pansus  Buloggate  itu Ilegal',
#        'Penambang Emas di Pasaman Tercemar Merkuri',
#        'Pelarian Modal ke Luar Negeri Tak Terhindarkan',
#        'Penggantian Pangdam Jaya untuk Antisipasi Keamanan Jakarta',
#        'Ditangkap, Oknum Brimob Edarkan Ganja 1,3 ton',
#        'Kisruh PB PTMSI Tak Pengaruhi Target SEA Games',
#        'Masyarakat Maluku di Belanda Akan Kunjungi Maluku',
#        'Rumah Pemilik TNT TMII di Jl Suwiryo Digeledah',
#        'Anggota Kapak Merah Tewas Diterjang Peluru Petugas',
#        'Megawati Minta Embargo Militer AS Dicabut',
#        'GMKI Jakarta Desak Pemda Perbaiki Kerusakan Akibat Bom',
#        'Investor di KTI akan Memperoleh Insentif Khusus',
#        'Terancam Tergusur, Warga Sekitar PLTU Ancol Timur Resah',
#        'Ada banyak kekecewaan di PAN',
#        'Sudi Silalahi Diusulkan Jadi Dirjen di Departemen Pertahanan',
#        'Silaturahmi Serikat Pekerja dan Buruh Akan Digelar',
#        'Pemain Nasional Ramaikan Kejurnas Bulutangkis di Banjarmasin',
#        'Hartono Minta Maaf Pada Saya',
#        'Iqbal Disebut Sebagai Koordinator Peledakan',
#        'Polda Jabar Sita 22 Ton Ajinomoto',
#        'Tepat, Langkah BI Membatasi Transaksi Valas',
#        'Langgar Prosedur, Pembelian Mobil Mewah Ketua DPRD Jabar',
#        'Kejagung Akan  Libatkan GJ Aditjondro Lacak Harta HMS',
#        'Osama Bin Laden Masih di Kandahar',
#        'Kenaikan Indeks Akibat Imbas Bursa Regional',
#        'Pemda Batal Lagi Lakukan Penertiban VCD Bajakan',
#        '"Kenapa Hanya Kasus Tommy Saja yang Disorot?"',
#        'Bush-Megawati akan Bicarakan Masalah Terorisme.',
#        'Uni Emirat Arab dan Kuwait Siap Pulangkan Pelajarnya dari AS',
#        'Jumlah Pengungsi 1,2 Juta',
#        'Kemitraan Usaha Harus Berdasar Kemampuan',
#        'Tukang Becak Minta Boleh beroperasi di Jakarta',
#        'Situasi Keamanan Wilayah Konflik Sudah Pulih',
#        'Megawati Tiba di Washington DC',
#        'Kapal Tipe A Polri Tidak Memenuhi Syarat Patroli',
#        'Polisi Tembak Dua Penodong',
#        'Perlu Proses Hukum untuk Selesaikan Kasus Madiun',
#        'KSAD Dukung Usulan Membentuk Koalisi Anti Teror',
#        'Balas Dendam Motif Dibalik Rencana Penyerangan AS',
#        'Kasus Kambing Tidak akan Renggangkan Hubungan RI-Arab Saudi',
#        'Megawati Bertemu Bush di Gedung Putih',
#        'Wapres Usul Pembuatan UU Anti-Teror',
#        'Indonesia Terancam Peningkatan Arus Pengungsi',
#        'Pengadilan Mixil Terhenti Karena Ricuh',
#        'Akbar Panggil Aberson Soal Cek Rp 10 Juta',
#        'Target Penerimaan 2002 Sangat Berat',
#        'Kejaksaan Agung Periksa Prajogo',
#        'DK PBB Serukan agar Taliban  Serahkan Osama',
#        'Pangkostrad Menon-aktifkan Danyon Linud 501 Madiun',
#        'Kunjungan Mega Tidak Bisa Banyak Diharapkan',
#        'Panglima Kostrad Jenguk Korban Madiun',
#        'Seorang Pendaki Gede-Pangrango Tewas',
#        'Belum Memberi Pengaruh ke Transportasi Laut',
#        'Pemda dan LSM Akan Bangun Barak', 'Fraksi Islam Amati Sidang',
#        'PT Arun NGL Ikut Hentikan Operasinya',
#        'ExxonMobil Hentikan Operasinya di Aceh',
#        'Kantor Pemerintah Dibakar, Kerugian Capai Rp 1 Miliar',
#        'Kuwait Berminat Bangun Kilang Minyak di Lombok Senilai US$ 1 Miliar',
#        'Koalisi Permanen Adalah Upaya Moratorium Politik',
#        'TNI Tidak Mungkin Ambil Alih Kekuasaan',
#        'Gus Dur Tak Bisa Diharapkan Gairahkan Otonomi Daerah',
#        'Pasokan Pertamina Berkurang, Harga Minyak Tanah Melonjak',
#        'Ada Upaya Rekayasa Memorandum II',
#        'GAM Berada Di Balik Pengaduan Itu',
#        'Puluhan Rumah Penduduk Dibongkar Paksa',
#        'DPRD Lampung Hanya Ciptakan Alasan Pembenar',
#        'Kasus Penembakan Mantan Rektor IAIN Terus Diusut',
#        'Proses Belajar di Aceh Timur Terganggu',
#        'Poso Sempat Tegang Kembali', 'Dua Partai Pertama Berakhir Remis',
#        'TNI Tak Tanggungjawab Semua Masalah Bangsa',
#        'Abdullah Puteh Tolak Jabatan Ketua Koni Aceh',
#        'Menhan Mengaku  Tak Tahu Menahu',
#        'Telkom dan Indosat Tidak Akan di-Merger',
#        'Keterlibatan Masyarakat Setempat Kunci Keberhasilan',
#        '25 LSM Tolak Pemberlakuan UU PKB',
#        'Kaditserse Bantah Felix Tidak Layak Diperiksa',
#        'Komisi IX DPR Setujui Restrukturisasi Utang Garuda',
#        'Hambat Arus Bongkar Muat di Pelabuhan Tanjungpriok',
#        '16 Pelajar Tertangkap Bawa Senjata Tajam',
#        'Keputusan Mennaker tentang Perburuhan Akan Ditinjau Ulang',
#        'Penundaan Kriteria  Delisting  BEJ Untuk Selamatkan Emiten',
#        'Pengungsi Tim-Tim Duduki Kantor Gubernur NTT',
#        'Keputusan Baru Tentang Perburuhan Perlu Ditinjau Ulang',
#        'Pungli Marak, Sopir Truk Aceh Ancam Mogok',
#        'Tim Ekonomi Akan Panggil Seluruh Pangdam dan Kapolda',
#        'Restrukturisasi Utang PT Timor Tunggu Keputusan KKSK',
#        'Aksi Tutup Mulut Usai Rapat PDIP',
#        'Keinginan Menko Perekonomian Sulit Direalisasikan',
#        'Jumat, Presiden Umumkan 11 Pejabat Eselon I Dephan',
#        'Dana Perbankan yang Tak Tersalurkan Rp 425 Triliun',
#        'Tarif Pengujian Kendaraan Bermotor Turun 75%',
#        'Ditindak, Oknum Perwira Yang Terlibat Insiden Batu Merah',
#        'Komisi I Gelar Public Hearing dengan Calon Dubes',
#        'Dua Anggota TNI Tewas Ditembak GAM',
#        'Kejenuhan Masyarakat Juga Akibat Pers',
#        'Polisi Didesak Periksa Juan Felix',
#        'Gempita Desak Kejagung Periksa Habibie-Wiranto-Ghalib',
#        'Polisi PNG Tangkap Panglima OPM', 'PKB Jatim Siap Perang',
#        'Pengacara Minta Elize Dibebaskan',
#        'HKTI Minta Pemerintah Lebih Perhatikan Nasib Petani',
#        'Turunkan Presiden Tanpa Konstitusi : Bughat',
#        'Minggu Depan Ghalib Dipanggil Kejaksaan Agung',
#        'Lingga Dalam Posisi Terjepit',
#        'Tommy Jadi Saksi Kasus Beddu Amang',
#        '"Kapal Asing Mulai Singgahi Sabang 20 Februari"',
#        'Massa Serbu Hotel Oasis Batam Karena Dianggap Sarang Judi',
#        'Kloter I Jemaah Haji Sumatera Utara Berangkat Jumat',
#        'Pemerintah Akan Terapkan Tiga Harga BBM',
#        'Belum Selesaikan 130 Butir Rancangan Amandemen UU BI',
#        'Polsek-Koramil Diserang, Sembilan Kios Hangus',
#        'Perdamaian Warga Tanah Abang Ditandatangani',
#        'Syamsul Nursalim Batal Diperiksa Kejakgung',
#        'Parpol Diminta Bantu Korban Bencana Alam',
#        'Tarif KIR Naik, Awak KWK Demo Pemda DKI',
#        'Polisi Tangkap Pemilik Senjata Ilegal',
#        'Pemerintah Tunda UU PKB, Usulkan RUU Keadaan Darurat',
#        'Dirgantara Indonesia Serahkan CN-235 Ke Perusahaan Filipina',
#        'Minta Menaker Mundur', 'KUD Segera Direstrukturisasi',
#        'Nota Pembelaan Bob setebal  215 Halaman.',
#        'Polda Tembak Mati 5 Penjahat Kapak Merah',
#        'Aparat Diadang, 100 Rumah Penduduk Jadi Abu',
#        'Fungsionaris DPW PAN NTB Mundur',
#        'Surat Penahanan Terhadap Ginandjar Kembali Dipersoalkan',
#        'Presiden Serahkan Sepenuhnya  Ke POM DAM Jaya',
#        'Tidak Ada Pertemuan Rahasia Antara Dubes AS dan GAM',
#        'Aksi "Siap Mati Syahid Membela Gus Dur" Patut Dihargai',
#        'Akbar Tak Keberatan Permintaan Megawati'], dtype=object)

# %%
#not super pythonic, no, not at all.
#use extend so it's a big flat list of vocab
from __future__ import print_function
totalvocab_stemmed = []
totalvocab_tokenized = []
dataarticle = list(df['desc'].values)
count = 0
for i in dataarticle:
    print("\rArticle process: {} from {}".format(count+1, len(dataarticle)), end="")
    count += 1
    allwords_stemmed = LIBS.tokenize_and_stem(i) #for each item in 'synopses', tokenize/stem
    totalvocab_stemmed.extend(allwords_stemmed) #extend the 'totalvocab_stemmed' list
    
    allwords_tokenized = LIBS.tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)
print ("")
print ("")

print ("total vacab stem: ", len(totalvocab_stemmed))
print ("total vacab tokenize: ",len(totalvocab_tokenized))
# Out:
# Article process: 200 from 200
#
# total vacab stem:  67283
# total vacab tokenize:  67283

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)
print ('there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame')
# vocab_frame[:10] #print 10 word
# Out:
# there are 67283 items in vocab_frame

# %%
from spacy.lang.id import stop_words
from string import punctuation, digits
from sklearn.feature_extraction.text import TfidfVectorizer

STWRD = list(set(punctuation))
STWRD += list(set(digits))
STWRD += stop_words.STOP_WORDS

tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                 min_df=2, stop_words=STWRD,
                                 use_idf=True, tokenizer=LIBS.tokenize_and_stem, ngram_range=(1,3))

# %time tfidf_matrix = tfidf_vectorizer.fit_transform(list(df['desc'].values)) #fit the vectorizer to synopses

print("TF-idf matrix: ",tfidf_matrix.shape)

terms = tfidf_vectorizer.get_feature_names()
# Out:
# CPU times: user 4.05 s, sys: 48 ms, total: 4.1 s
# Wall time: 4.1 s
# TF-idf matrix:  (200, 5025)

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(tfidf_matrix)
print
dist
# Out:
# array([[ 0.00000000e+00,  9.79476169e-01,  9.72925887e-01, ...,
#          9.92760477e-01,  9.78366144e-01,  9.88338691e-01],
#        [ 9.79476169e-01, -2.22044605e-16,  9.71918346e-01, ...,
#          9.54412367e-01,  9.89025385e-01,  9.44775538e-01],
#        [ 9.72925887e-01,  9.71918346e-01, -1.33226763e-15, ...,
#          9.95891123e-01,  9.79888322e-01,  9.65653518e-01],
#        ...,
#        [ 9.92760477e-01,  9.54412367e-01,  9.95891123e-01, ...,
#          0.00000000e+00,  9.72231220e-01,  8.97410196e-01],
#        [ 9.78366144e-01,  9.89025385e-01,  9.79888322e-01, ...,
#          9.72231220e-01,  1.11022302e-16,  9.73226896e-01],
#        [ 9.88338691e-01,  9.44775538e-01,  9.65653518e-01, ...,
#          8.97410196e-01,  9.73226896e-01, -2.22044605e-16]])

# %%
from sklearn.cluster import KMeans

num_clusters = 4

km = KMeans(n_clusters=num_clusters)

# %time km.fit(tfidf_matrix)

clusters = km.labels_.tolist()
# Out:
# CPU times: user 520 ms, sys: 0 ns, total: 520 ms
# Wall time: 519 ms

# %%
from sklearn.externals import joblib

#uncomment the below to save your model 
#since I've already run my model I am loading from the pickle

joblib.dump(km,  'rep_23072018.pkl')
# 
# km = joblib.load('rep_23072018.pkl')
clusters = km.labels_.tolist()

# %%
films = { 'title': list(df['title'].values), 'desc': list(df['desc'].values), 'cluster': clusters }

frame = pd.DataFrame(films, index = [clusters] , columns = ['title', 'desc','cluster'])
frame
# Out:
#                                                 title  \
# 1        Akri Patrio Masuk Ruang Isolasi RS Pertamina
# 0                Bambang Kesowo Bantah Telepon Taufik
# 3                        Yusril Datang ke LP Cipinang
# 1   Penyelidikan Pelanggaran HAM Tidak Terkait den...
# 3                     200 Ribu Gula Impor Salahi Izin
# 3                 Korban Tewas di Cipinang Satu Orang
# 1            Warga PDI-P agar Bersikap Anti Kekerasan
# 3            Puluhan Senjata Tajam Disita di Cipinang
# 1                            Indeks Melemah di Sesi I
# 1     Eko dan Akri Patrio Terbakar, Masuk Rumah Sakit
# 3                       LP Cipinang Rusuh, Satu Tewas
# 3   Wakil Gubernur Sulawesi Utara Freddy H. Sualan...        3
# 3   Ribuan armada Angkutan Umum yang tergabung dal...        3
# 3   Tempat transaksi senjata api ilegal di wilayah...        3
# 1   Pemerintah akhirnya memutuskan menunda untuk m...        1
# 1   PT Dirgantara Indonesia, dulu bernama IPTN, Ka...        1
# 1   Sekitar 200 buruh PT Indometal Sejati Kedaung,...        1
# 1   Pemerintah akan segera melakukan restrukturisa...        1
# 1   Terdakwa Mohamad Hasan atau Bob Hassan membaca...        1
# 3   Dalam operasi mulai 15 hingga 20 Januari, apar...        3
# 3   Ekses dari penembakan yang dilakukan gerilyawa...        3
# 1   Gelombang pengunduran pengurus Partai Amanat N...        1
# 0   Surat izin penahanan terhadap mantan Menteri P...        0
# 1   Juru Bicara Kepresidenan Adhi M Massardi menga...        1
# 1   Menteri Luar Negeri Alwi Shihab membantah adan...        1
# 2   Ketua Yayasan Paramadina, Dr Komaruddin Hidaya...        2
# 1   Partai Golkar tidak mempermasalahkan permintaa...        1
#
# [200 rows x 3 columns]

# %%
frame['cluster'].value_counts() #number of article per cluster (clusters from 0 to 4)
# Out:
# 1    96
# 3    60
# 0    25
# 2    19
# Name: cluster, dtype: int64

# %%
from __future__ import print_function

print("Top terms per cluster:")
print()
#sort cluster centers by proximity to centroid
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 

for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
    print() #add whitespace
    print() #add whitespace
    
    print("Cluster %d titles:" % i, end='')
    for title in frame.ix[i]['title'].values.tolist():
        print(' %s,' % title, end='')
    print() #add whitespace
    print() #add whitespace
    
print()
print()
# Out:
# Top terms per cluster:
#
# Cluster 0 words: tommy, agung, soeharto, kejaksaan, pk, keputusan,
#
# Cluster 0 titles: Bambang Kesowo Bantah Telepon Taufik, MA Bertindak Heroik dalam PK Tommy, Pengacara Tommy Minta Salinan Keputusan ke MA, Wapres Berharap Masyarakat Hormati Putusan MA, Putusan PK Tommy Atas Sepengetahuan Rapim MA, M. Taufik Sadar Keputusannya Kontroversial, Tommy Serahkan Diri Oktober Ini, Majelis Hakim Memutus Dengan Sangat Hati-hati, Kejagung Bisa Lakukan PK Terhadap Keputusan PK MA, MA Memberi Contoh Buruk dalam Pelaksanaan Hukum, Keputusan MA Bukan Karena Tewasnya Syafiuddin, Tommy Tak Menampakkan Diri di Cendana, KPKPN Telah Terima Daftar Kekayaan 56 Hakim Agung, Kejagung Sulit Menyusun Dakwaan Beddu, Rumah Pemilik TNT TMII di Jl Suwiryo Digeledah, Kejagung Akan  Libatkan GJ Aditjondro Lacak Harta HMS, "Kenapa Hanya Kasus Tommy Saja yang Disorot?", Kejaksaan Agung Periksa Prajogo, Kaditserse Bantah Felix Tidak Layak Diperiksa, Polisi Didesak Periksa Juan Felix, Gempita Desak Kejagung Periksa Habibie-Wiranto-Ghalib, Pengacara Minta Elize Dibebaskan, Minggu Depan Ghalib Dipanggil Kejaksaan Agung, Tommy Jadi Saksi Kasus Beddu Amang, Surat Penahanan Terhadap Ginandjar Kembali Dipersoalkan,
#
# Cluster 1 words: pemerintah, indonesia, presiden, as, saham, mengungsi,
#
7/site-packages/ipykernel_launcher.py:17: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
import os  # for os.path.basename

import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.manifold import MDS

MDS()

# convert two components as we're plotting points in a two-dimensional plane
# "precomputed" because we provide a distance matrix
# we will also specify `random_state` so the plot is reproducible.
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1)

pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

xs, ys = pos[:, 0], pos[:, 1]
print()
print()

# %%
#set up colors per clusters using a dict
cluster_colors = {0: '#e6194b', 1: '#3cb44b', 2: '#ffe119', 3: '#0082c8'}

#set up cluster names using a dict
cluster_names = {0: 'Family', 
                 1: 'Police', 
                 2: 'Father', 
                 3: 'Dance', 
                 4: 'Killed'}

# %%
#some ipython magic to show the matplotlib plots inline
# %matplotlib inline 
# import mpld3
# mpld3.enable_notebook()

#create data frame that has the result of the MDS plus the cluster numbers and titles
df = pd.DataFrame(dict(x=xs, y=ys, label=clusters, title=list(df['title'].values))) 

#group by cluster
groups = df.groupby('label')


# set up plot
fig, ax = plt.subplots(figsize=(40, 20)) # set size
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling

#iterate through groups to layer the plot|
#note that I use the cluster_name and cluster_color dicts with the 'name' lookup to return the appropriate color/label
for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, 
            label=cluster_names[name], 
            color=cluster_colors[name], 
            mec='none')
    ax.set_aspect('auto')
    ax.tick_params(\
        axis= 'x',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelbottom='off')
    ax.tick_params(\
        axis= 'y',         # changes apply to the y-axis
        which='both',      # both major and minor ticks are affected
        left='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelleft='off')
    
ax.legend(numpoints=1)  #show legend with only 1 point

#add label in x,y position with the label as the film title
for i in range(len(df)):
    ax.text(df.ix[i]['x'], df.ix[i]['y'], df.ix[i]['title'], size=8)  

    
    
plt.show() #show the plot

#uncomment the below to save the plot if need be
# plt.savefig('clusters_small_noaxes.png', dpi=200)
# Out:
# /home/notula/PycharmProjects/clustering/env/local/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /home/notula/PycharmProjects/clustering/env/lib/python2.7/site-packages/ipykernel_launcher.py:40: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
plt.close()

# %%
#define custom toolbar location
class TopToolbar(mpld3.plugins.PluginBase):
    """Plugin for moving toolbar to top of figure"""

    JAVASCRIPT = """
    mpld3.register_plugin("toptoolbar", TopToolbar);
    TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
    TopToolbar.prototype.constructor = TopToolbar;
    function TopToolbar(fig, props){
        mpld3.Plugin.call(this, fig, props);
    };

    TopToolbar.prototype.draw = function(){
      // the toolbar svg doesn't exist
      // yet, so first draw it
      this.fig.toolbar.draw();

      // then change the y position to be
      // at the top of the figure
      this.fig.toolbar.toolbar.attr("x", 150);
      this.fig.toolbar.toolbar.attr("y", 400);

      // then remove the draw function,
      // so that it is not called again
      this.fig.toolbar.draw = function() {}
    }
    """
    def __init__(self):
        self.dict_ = {"type": "toptoolbar"}

# %%
#create data frame that has the result of the MDS plus the cluster numbers and titles
df = pd.DataFrame(dict(x=xs, y=ys, label=clusters, title=list(df['title'].values))) 

#group by cluster
groups = df.groupby('label')

#define custom css to format the font and to remove the axis labeling
css = """
text.mpld3-text, div.mpld3-tooltip {
  font-family:Arial, Helvetica, sans-serif;
}

g.mpld3-xaxis, g.mpld3-yaxis {
display: none; }

svg.mpld3-figure {
margin-left: -200px;}
"""

# Plot 
fig, ax = plt.subplots(figsize=(14,6)) #set plot size
ax.margins(0.03) # Optional, just adds 5% padding to the autoscaling

#iterate through groups to layer the plot
#note that I use the cluster_name and cluster_color dicts with the 'name' lookup to return the appropriate color/label
for name, group in groups:
    points = ax.plot(group.x, group.y, marker='o', linestyle='', ms=18, 
                     label=cluster_names[name], mec='none', 
                     color=cluster_colors[name])
    ax.set_aspect('auto')
    labels = [i for i in group.title]
    
    #set tooltip using points, labels and the already defined 'css'
    tooltip = mpld3.plugins.PointHTMLTooltip(points[0], labels,
                                       voffset=10, hoffset=10, css=css)
    #connect tooltip to fig
    mpld3.plugins.connect(fig, tooltip, TopToolbar())    
    
    #set tick marks as blank
    ax.axes.get_xaxis().set_ticks([])
    ax.axes.get_yaxis().set_ticks([])
    
    #set axis as blank
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)

    
ax.legend(numpoints=1) #show legend with only one dot

mpld3.display() #show the plot

#uncomment the below to export to html
#html = mpld3.fig_to_html(fig)
#print(html)
# Out:
# <style>
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# </style>
#
# <div id="fig_el187041403231198146082334595083"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null,
#                                                 hoffset:0,
#                                                 voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                   tooltip
#                     .style("top", d3.event.pageY + this.props.voffset + "px")
#                     .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null,
#                                                 hoffset:0,
#                                                 voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                   tooltip
#                     .style("top", d3.event.pageY + this.props.voffset + "px")
#                     .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null,
#                                                 hoffset:0,
#                                                 voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                   tooltip
#                     .style("top", d3.event.pageY + this.props.voffset + "px")
#                     .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     Html

# %%
from scipy.cluster.hierarchy import ward, dendrogram

linkage_matrix = ward(dist) #define the linkage_matrix using ward clustering pre-computed distances

fig, ax = plt.subplots(figsize=(15, 20)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=list(df['title'].values));

plt.tick_params(\
    axis= 'x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

#uncomment below to save figure
plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters

# %%
#strip any proper names from a text...unfortunately right now this is yanking the first word from a sentence too.
import string
def strip_proppers(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent) if word.islower()]
    return "".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in tokens]).strip()

# %%
#strip any proper nouns (NNP) or plural proper nouns (NNPS) from a text
from nltk.tag import pos_tag

def strip_proppers_POS(text):
    tagged = pos_tag(text.split()) #use NLTK's part of speech tagger
    non_propernouns = [word for word,pos in tagged if pos != 'NNP' and pos != 'NNPS']
    return non_propernouns

# %%
dataarticle1 = []
for x in dataarticle:
    dataarticle1.append(x)
dataarticle = dataarticle1

# %%
from gensim import corpora, models, similarities 

#remove proper names
# %time preprocess = [strip_proppers(doc) for doc in dataarticle]

#tokenize
# %time tokenized_text = [LIBS.tokenize_and_stem(text) for text in preprocess]

#remove stop words
# %time texts = [[word for word in text if word not in STWRD] for text in tokenized_text]
# Out:
# CPU times: user 604 ms, sys: 4 ms, total: 608 ms
# Wall time: 607 ms
# CPU times: user 2.74 s, sys: 8 ms, total: 2.75 s
# Wall time: 2.75 s
# CPU times: user 412 ms, sys: 4 ms, total: 416 ms
# Wall time: 411 ms

# %%
#create a Gensim dictionary from the texts
dictionary = corpora.Dictionary(texts)

#remove extremes (similar to the min/max df step used when creating the tf-idf matrix)
dictionary.filter_extremes(no_below=1, no_above=0.8)

#convert the dictionary to a bag of words corpus for reference
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
# %time lda = models.LdaModel(corpus, num_topics=5,  id2word=dictionary,  update_every=5,  chunksize=10000,  passes=100)
# Out:
# CPU times: user 12.2 s, sys: 36 ms, total: 12.2 s
# Wall time: 12.2 s

# %%
lda.show_topics()
# Out:
# [(0,
#   u'0.017*"laku" + 0.011*"polisi" + 0.010*"orang" + 0.010*"hasil" + 0.009*"anggota" + 0.008*"warga" + 0.008*"jalan" + 0.008*"tembak" + 0.007*"aparat" + 0.007*"kitar"'),
#  (1,
#   u'0.014*"perintah" + 0.009*"pilih" + 0.009*"negara" + 0.009*"politik" + 0.009*"orang" + 0.008*"hadap" + 0.008*"laku" + 0.008*"nyata" + 0.007*"dukung" + 0.007*"putus"'),
#  (2,
#   u'0.017*"perintah" + 0.009*"putus" + 0.008*"hukum" + 0.007*"daerah" + 0.007*"hakim" + 0.007*"usaha" + 0.007*"temu" + 0.007*"masyarakat" + 0.006*"perkara" + 0.006*"rupa"'),
#  (3,
#   u'0.016*"saham" + 0.009*"persen" + 0.008*"bunga" + 0.008*"milik" + 0.008*"rupiah" + 0.007*"turun" + 0.007*"bank" + 0.007*"nilai" + 0.007*"indeks" + 0.006*"perintah"'),
#  (4,
#   u'0.011*"buruh" + 0.011*"orang" + 0.009*"harga" + 0.008*"usaha" + 0.008*"kerja" + 0.007*"laku" + 0.007*"perintah" + 0.006*"temu" + 0.006*"korban" + 0.006*"aman"')]

# %%
# topics_matrix

# %%
topics_matrix = lda.show_topics(formatted=False, num_words=20